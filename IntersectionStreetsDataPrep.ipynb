# %%
import pandas as pd
# the original intersection data that will be enriched with addtional variables
inter_collis_df = pd.DataFrame.from_csv("./OBJ2B_collisions_intersections.csv")

# alex's predicted street exposure (adt) that will be joined with the streets column of intersection data
street_exp_pred_df = pd.DataFrame.from_csv("../o1_se_result2.tsv", sep="\t")

# original street exposure data that will be selectively joined with streets column of intersection data
street_exp_orig_df = pd.DataFrame.from_csv("./OBJ1_streets_exposure.csv")

# index street data on unitidsort
street_exp_orig_df = street_exp_orig_df.set_index(['unitidsort'])

# %%
# join in all vars from predicted exposure
# results in a new column with list of lists: outer list for each street and inner lists of predicted exposure vars
inter_collis_df["exp_pred_vars"] = inter_collis_df.streets.apply(lambda x: [street_exp_pred_df.ix[int(y)] for y in x.split(',')])

# %%
inter_collis_df["exp_pred_vars"].head(2)
# Out:
# 0    [[13345.0, 13312.4799607, 9.49645721715], [162...
# 1    [[nan, 3076.16862581, 8.03144014896], [nan, 39...
# Name: exp_pred_vars, dtype: object

# %%
# join in all vars from predicted exposure
# results in a new column with list of lists: outer list for each street and inner lists of predicted exposure vars
inter_collis_df["street_vars"] = inter_collis_df.streets.apply(lambda x: [street_exp_orig_df.ix[int(y)] for y in x.split(',')])

# %%
inter_collis_df["street_vars"].head(2)
# Out:
# 0    [[10075, DEXTER AVE N, DEXTER AVE N BETWEEN RE...
# 1    [[9725, COLUMBIA ST, COLUMBIA ST BETWEEN ALASK...
# Name: street_vars, dtype: object

# %%
# next we want to perform some aggregations

# these are helper functions that will be used to aggregate over a particular column of street-level data
import math
import sys

def sum_over_streets(column, street_data):
    result = 0
    for street in street_data:
        result += street[column]
        
    return result

def uniq_values(column, street_data):
    values = set()
    for street in street_data:
        values.add(street[column])
        
    return len(values)

def min_known_value(column, street_data):
    minimum = sys.maxint
    for street in street_data:
        if not math.isnan(street[column]):
            if street[column] < minimum:
                minimum = street[column]
        
    if minimum == sys.maxint:
        return float('NaN')
    else:
        return minimum

def min_nonzero_value(column, street_data):
    minimum = sys.maxint
    for street in street_data:
        if street[column] != 0 and street[column] < minimum:
            minimum = street[column]
        
    if minimum == sys.maxint:
        return float('NaN')
    else:
        return minimum

def avg_of_known_values(column, street_data):
    total = 0
    count = 0
    for street in street_data:
        if not math.isnan(street[column]):
            total += street[column]
            count += 1
    if count == 0:
        return float('NaN')
    else:
        return total / float(count)
    
def avg_of_nonzero_values(column, street_data):
    total = 0
    count = 0
    for street in street_data:
        if not street[column] == 0:
            total += street[column]
            count += 1
    if count == 0:
        return float('NaN')
    else:
        return total / float(count)

def bool_true_count(column, street_data):
    count = 0
    for street in street_data:
        if street[column]:
            count += 1
        
    return count

# %%
# add variable intersection_adt_hat2: adt_hat2 summed over all streets (and divided by 2)
inter_collis_df["intersection_adt_hat2"] = inter_collis_df.exp_pred_vars.apply(lambda x: sum_over_streets(1, x) / 2.0)

# %%
# add variable zoning_cats: number of unique zoning categories over all streets divided by number of streets
inter_collis_df["zoning_cats"] = inter_collis_df.street_vars.apply(lambda x: uniq_values(4, x) / float(len(x)))

# %%
# add variable min_pavement_cond: min known value of pavement condition index over all streets (some are unknown)
inter_collis_df["min_pavement_cond"] = inter_collis_df.street_vars.apply(lambda x: min_nonzero_value(5, x))

# %%
# add variable avg_pavement_cond: avg value of known pavement condition index over all streets (some are unknown)
inter_collis_df["avg_pavement_cond"] = inter_collis_df.street_vars.apply(lambda x: avg_of_nonzero_values(5, x))

# %%
# add variable pct_truck_routes: percentage of truck routes over all streets
inter_collis_df["pct_truck_routes"] = inter_collis_df.street_vars.apply(lambda x: bool_true_count(6, x) / float(len(x)))

# %%
# add variable min_surface_width: min value of known surface widths over all streets (some are unknown)
inter_collis_df["min_surface_width"] = inter_collis_df.street_vars.apply(lambda x: min_known_value(9, x))

# %%
# add variable avg_surface_width: average value of known surface widths over all streets (some are unknown)
inter_collis_df["avg_surface_width"] = inter_collis_df.street_vars.apply(lambda x: avg_of_known_values(9, x))

# %%
# add variable pct_oneway: percentage of oneway over all streets
inter_collis_df["pct_oneway"] = inter_collis_df.street_vars.apply(lambda x: bool_true_count(10, x) / float(len(x)))

# %%
inter_collis_df["intersection_adt_hat2"].head(2)
# Out:
# 0    35221.303413
# 1     8186.717943
# Name: intersection_adt_hat2, dtype: float64

# %%
inter_collis_df["pct_oneway"].head(10)
# Out:
# 0    0.250000
# 1    0.500000
# 2    0.000000
# 3    0.000000
# 4    0.500000
# 5    0.000000
# 6    0.000000
# 7    0.500000
# 8    0.000000
# 9    0.333333
# Name: pct_oneway, dtype: float64

# %%
inter_collis_df
# Out:
#          gid    segkey  intkey                               location  \
# 0      38565   10076.0   28767             DEXTER AVE N AND MERCER ST
# 1      48114    9726.0   30352            COLUMBIA ST AND WESTERN AVE
# 2         12    3659.0   33983           24TH AVE SW AND SW HOLDEN ST
# 3         23    8973.0   37326             AURORA AVE N AND N 94TH ST
# 4         28    1411.0   25790             11TH AVE NE AND NE 50TH ST
# 5         36    8985.0   36360       AURORA AVE N AND N NORTHGATE WAY
# 6         74    9312.0   29940              BOREN AVE AND COLUMBIA ST
# 7        122   11068.0   28661           JOHN ST AND QUEEN ANNE AVE N
# 8        139    4375.0   30480                   3RD AVE AND JAMES ST
# 9        171    2031.0   27145        15TH AVE NE AND NE CAMPUS WB PY
# 10       188    8871.0   37373           ASHWORTH AVE N AND N 85TH ST
# 11       231    2651.0   30125              19TH AVE AND E MADISON ST
# 12       353    2535.0   30192            18TH AVE AND E JEFFERSON ST
# 13       374    9444.0   29772                BROADWAY AND MADISON ST
# 14       400    9375.0   29734             BOYLSTON AVE AND E PINE ST
# 15       405  275587.0   24350          GREENWOOD AVE N AND N 67TH ST
# 16       472    8158.0   29895                    7TH AVE AND PIKE ST
# 17       487    8280.0   29893                    8TH AVE AND PIKE ST
# 18       507    1190.0   30381         1ST AVE S AND RAILROAD N WAY S
# 19       514    9447.0   29745                 BROADWAY AND E PIKE ST
# 20       531    1550.0   29064               12TH AVE AND E DENNY WAY
# 21       566    2748.0   30488                 2ND AVE AND YESLER WAY
# 22       598    4633.0   36602            30TH AVE NE AND NE 125TH ST
# 23       604   11968.0   27044             DRAVUS ST AND NICKERSON ST
# 24       656   21820.0   32143        SW AVALON WAY AND SW GENESEE ST
# 25       662    9478.0   27141    BROOKLYN AVE NE AND NE CAMPUS WB PY
# 26       728   10016.0   29508                DENNY WAY AND TERRY AVE
# 27       733   10458.0   28049          FLORENTIA ST AND WARREN AVE N
# 28       777    3553.0   28428               24TH AVE E AND E LYNN ST
# 29       809   12382.0   32715       RAINIER AVE S AND S GENESEE S ST
# ...      ...       ...     ...                                    ...
# 6168  168543   12971.0   25562              STONE WAY N AND N 47TH ST
# 6169  168559    3725.0   25939             25TH AVE NE AND NE 55TH ST
# 6170  168811    8992.0   35847            AURORA AVE N AND N 125TH ST
# 6171  168910   10181.0   28287         EASTLAKE AVE E AND E HAMLIN ST
# 6172  168937    5359.0   24971             35TH AVE NE AND NE 65TH ST
# 6173  168996    2772.0   29660                  2ND AVE AND DENNY WAY
# 6174  168999   15233.0   35587             1ST AVE NW AND NW 143RD ST
# 6175  169044    8152.0   29962                   7TH AVE AND JAMES ST
# 6176  169052    8990.0   36342            AURORA AVE N AND N 115TH ST
# 6177  169220   12189.0   29598                    PIKE PL AND PIKE ST
# 6178  169224    4382.0   29601              3RD AVE AND UNIVERSITY ST
# 6179  169235    4388.0   29558                  3RD AVE AND LENORA ST
# 6180  169260    1785.0   31315            13TH AVE S AND S STEVENS ST
# 6181  169275    9484.0   25792         BROOKLYN AVE NE AND NE 50TH ST
# 6182  169350    8523.0   29868                  9TH AVE AND HOWELL ST
# 6183  169389    9694.0   35427      RAINIER AVE S AND S CLOVERDALE ST
# 6184  169498    8668.0   31299        AIRPORT WAY S AND S LANDER N ST
# 6185  169503    2038.0   26051             15TH AVE NE AND NE 52ND ST
# 6186  169506    3723.0   25949         25TH AVE NE AND NE BLAKELEY ST
# 6187  169525    1338.0   35095         10TH AVE S AND S CLOVERDALE ST
# 6188  169576    9309.0   29817             BOREN AVE AND JEFFERSON ST
# 6189  169590    9214.0   29855            BELLEVUE AVE AND E OLIVE ST
# 6190  169597   12653.0   36501  ROOSEVELT WAY NE AND NE NORTHGATE WAY
# 6191  169811   11910.0   27299     MONTLAKE BLVD NE AND NE PACIFIC ST
# 6192  169865    8529.0   29512                  BELL ST AND DENNY WAY
# 6193  169866   14219.0   29810            11TH AVE AND E JEFFERSON ST
# 6194  170000    2028.0   27149          15TH AVE NE AND NE PACIFIC ST
# 6195  170027    9319.0   29878                  BOREN AVE AND PIKE ST
# 6196  170092    1997.0   30136              15TH AVE AND E MADISON ST
# 6197  170095    2019.0   28944              15TH AVE E AND E GALER ST
#
#                      incdttm      yr   mon    hr  dow    col_type     ...      \
# 0       5/26/2006 2:35:00 PM  2006.0   5.0  14.0  5.0      Cycles     ...
# 1       1/25/2005 5:10:00 PM  2005.0   1.0  17.0  2.0      Cycles     ...
# 2                   9/4/2008  2008.0   9.0   NaN  4.0      Cycles     ...
# 3      1/16/2008 12:02:00 PM  2008.0   1.0  12.0  3.0      Cycles     ...
# 4                   6/9/2008  2008.0   6.0   NaN  1.0  Pedestrian     ...
# 5       6/23/2008 5:14:00 PM  2008.0   6.0  17.0  1.0  Pedestrian     ...
# 6      12/10/2008 1:06:00 PM  2008.0  12.0  13.0  3.0  Pedestrian     ...
# 7       7/24/2008 1:36:00 PM  2008.0   7.0  13.0  4.0      Cycles     ...
# 8       9/29/2008 3:54:00 PM  2008.0   9.0  15.0  1.0  Pedestrian     ...
# 9       9/19/2008 3:05:00 PM  2008.0   9.0  15.0  5.0  Pedestrian     ...
# 10     2/28/2008 12:53:00 PM  2008.0   2.0  12.0  4.0      Cycles     ...
# 11                 11/3/2008  2008.0  11.0   NaN  1.0  Pedestrian     ...
# 12     7/24/2008 10:30:00 PM  2008.0   7.0  22.0  4.0      Cycles     ...
# 13     8/23/2008 12:34:00 PM  2008.0   8.0  12.0  6.0  Pedestrian     ...
# 14                  4/1/2008  2008.0   4.0   NaN  2.0      Cycles     ...
# 15                  2/7/2008  2008.0   2.0   NaN  4.0      Cycles     ...
# 16                  1/8/2008  2008.0   1.0   NaN  2.0  Pedestrian     ...
# 17      5/29/2008 5:10:00 PM  2008.0   5.0  17.0  4.0  Pedestrian     ...
# 18     3/30/2008 12:49:00 AM  2008.0   3.0   0.0  0.0  Pedestrian     ...
# 19      5/21/2008 9:15:00 PM  2008.0   5.0  21.0  3.0      Cycles     ...
# 20     2/29/2008 12:22:00 AM  2008.0   2.0   0.0  5.0  Pedestrian     ...
# 21                 11/3/2008  2008.0  11.0   NaN  1.0      Cycles     ...
# 22                  2/9/2008  2008.0   2.0   NaN  6.0  Pedestrian     ...
# 23      3/10/2008 6:43:00 AM  2008.0   3.0   6.0  1.0  Pedestrian     ...
# 24    12/12/2008 10:20:00 PM  2008.0  12.0  22.0  5.0  Pedestrian     ...
# 25      4/22/2008 1:15:00 PM  2008.0   4.0  13.0  2.0      Cycles     ...
# 26     10/14/2008 3:34:00 PM  2008.0  10.0  15.0  2.0      Cycles     ...
# 27     10/15/2008 1:55:00 PM  2008.0  10.0  13.0  3.0      Cycles     ...
# 28      3/13/2008 9:18:00 AM  2008.0   3.0   9.0  4.0  Pedestrian     ...
# 29      1/15/2008 4:41:00 PM  2008.0   1.0  16.0  2.0  Pedestrian     ...
# ...                      ...     ...   ...   ...  ...         ...     ...
# 6168   11/10/2007 5:20:00 PM  2007.0  11.0  17.0  6.0  Pedestrian     ...
# 6169   10/25/2008 5:13:00 PM  2008.0  10.0  17.0  6.0  Pedestrian     ...
# 6170    1/27/2016 9:30:00 PM  2016.0   1.0  21.0  3.0  Pedestrian     ...
# 6171    1/26/2016 9:45:00 AM  2016.0   1.0   9.0  2.0  Pedestrian     ...
# 6172    1/27/2016 6:45:00 AM  2016.0   1.0   6.0  3.0  Pedestrian     ...
# 6173    9/21/2007 1:20:00 PM  2007.0   9.0  13.0  5.0  Pedestrian     ...
# 6174    5/16/2006 6:30:00 AM  2006.0   5.0   6.0  2.0      Cycles     ...
# 6175                3/6/2006  2006.0   3.0   NaN  1.0  Pedestrian     ...
# 6176                3/5/2008  2008.0   3.0   NaN  3.0  Pedestrian     ...
# 6177   10/14/2004 6:36:00 PM  2004.0  10.0  18.0  4.0  Pedestrian     ...
# 6178    3/25/2013 8:45:00 AM  2013.0   3.0   8.0  1.0  Pedestrian     ...
# 6179   2/12/2004 12:28:00 PM  2004.0   2.0  12.0  4.0  Pedestrian     ...
# 6180   3/25/2013 10:57:00 PM  2013.0   3.0  22.0  1.0      Cycles     ...
# 6181                8/9/2004  2004.0   8.0   NaN  1.0      Cycles     ...
# 6182               12/9/2004  2004.0  12.0   NaN  4.0  Pedestrian     ...
# 6183   10/24/2005 4:00:00 PM  2005.0  10.0  16.0  1.0  Pedestrian     ...
# 6184    3/26/2013 9:00:00 AM  2013.0   3.0   9.0  2.0  Pedestrian     ...
# 6185     3/7/2013 8:37:00 PM  2013.0   3.0  20.0  4.0  Pedestrian     ...
# 6186    6/15/2005 7:12:00 PM  2005.0   6.0  19.0  3.0      Cycles     ...
# 6187     4/2/2013 7:15:00 PM  2013.0   4.0  19.0  2.0      Cycles     ...
# 6188     4/2/2013 6:42:00 PM  2013.0   4.0  18.0  2.0      Cycles     ...
# 6189    3/30/2013 8:30:00 PM  2013.0   3.0  20.0  6.0      Cycles     ...
# 6190    3/30/2013 8:47:00 PM  2013.0   3.0  20.0  6.0  Pedestrian     ...
# 6191    3/28/2013 7:03:00 PM  2013.0   3.0  19.0  4.0  Pedestrian     ...
# 6192    3/26/2013 6:12:00 PM  2013.0   3.0  18.0  2.0      Cycles     ...
# 6193    3/29/2013 6:10:00 PM  2013.0   3.0  18.0  5.0      Cycles     ...
# 6194    3/28/2013 3:30:00 PM  2013.0   3.0  15.0  4.0      Cycles     ...
# 6195   3/29/2013 11:53:00 AM  2013.0   3.0  11.0  5.0      Cycles     ...
# 6196    1/26/2016 5:06:00 PM  2016.0   1.0  17.0  2.0      Cycles     ...
# 6197    1/14/2016 6:46:00 PM  2016.0   1.0  18.0  4.0  Pedestrian     ...
#
#                                           exp_pred_vars  \
# 0     [[13345.0, 13312.4799607, 9.49645721715], [162...
# 1     [[nan, 3076.16862581, 8.03144014896], [nan, 39...
# 2     [[1144.0, 1186.61833439, 7.0788628049], [1370....
# 3     [[nan, 35456.1592898, 10.4760522627], [40130.0...
# 4     [[7103.0, 7225.37454417, 8.88535435166], [nan,...
# 5     [[35556.0, 36104.1848969, 10.4941640627], [348...
# 6     [[nan, 18565.939044, 9.82908394675], [19328.0,...
# 7     [[1544.0, 1563.7808079, 7.35486176288], [9327....
# 8     [[6932.0, 6991.98010705, 8.85251907223], [7583...
# 9     [[nan, 18309.5685432, 9.8151790734], [13497.0,...
# 10    [[nan, 231.945950764, 5.44650437368], [nan, 64...
# 11    [[3412.0, 3669.31382418, 8.20775995468], [5898...
# 12    [[1116.0, 1087.47200026, 6.99161101574], [678....
# 13    [[15724.0, 16152.0025849, 9.68979932003], [149...
# 14    [[1650.0, 1599.51651816, 7.37745668641], [1490...
# 15    [[nan, 349.399198941, 5.85621510503], [nan, 13...
# 16    [[9157.0, 8657.49674189, 9.06618089994], [8779...
# 17    [[5484.0, 5490.17641453, 8.61071566778], [5271...
# 18    [[13184.0, 12921.0576644, 9.46661363656], [nan...
# 19    [[16856.0, 16600.5845305, 9.71719318641], [178...
# 20    [[nan, 11014.7135827, 9.30698725642], [10374.0...
# 21    [[10185.0, 10473.786473, 9.25663088825], [6503...
# 22    [[7229.0, 7167.40462106, 8.87729889053], [8959...
# 23    [[962.0, 929.519168439, 6.83466742926], [24732...
# 24    [[12613.0, 12402.7782093, 9.42567577563], [112...
# 25    [[nan, 2869.81685866, 7.9620034944], [5532.0, ...
# 26    [[37731.0, 37633.6668293, 10.5356543231], [nan...
# 27    [[nan, 3859.48053453, 8.25828787685], [3786.0,...
# 28    [[20050.0, 19274.4934752, 9.86653791924], [221...
# 29    [[29416.0, 28243.6175623, 10.2486227841], [269...
# ...                                                 ...
# 6168  [[nan, 11112.5676834, 9.31583197055], [9696.33...
# 6169  [[21256.0, 20834.340549, 9.94435789224], [1569...
# 6170  [[36870.0, 36942.7186901, 10.5171238485], [369...
# 6171  [[16440.0, 16222.9732482, 9.6941836184], [1708...
# 6172  [[10893.0, 11149.9124672, 9.31918692638], [128...
# 6173  [[nan, 6037.29272123, 8.70571096548], [3176.0,...
# 6174  [[nan, 824.832576702, 6.71518042841], [nan, 10...
# 6175  [[9398.0, 9723.18316134, 9.18226832958], [1117...
# 6176  [[35145.0, 34016.185981, 10.4345917486], [4111...
# 6177  [[nan, 2728.98721137, 7.9116858345], [nan, 125...
# 6178  [[8786.0, 8797.58979638, 9.08223307618], [9955...
# 6179  [[8183.0, 8175.88268071, 9.00894396311], [7532...
# 6180  [[nan, 849.404512317, 6.74453553022], [nan, 70...
# 6181  [[6875.0, 6893.40325231, 8.83832018289], [4356...
# 6182  [[2514.0, 2366.76965554, 7.76928128984], [3497...
# 6183  [[1603.0, 1723.48348902, 7.452102806], [19924....
# 6184  [[19800.0, 19342.1682165, 9.8700428732], [1918...
# 6185  [[7474.0, 7619.94373852, 8.93852426526], [9192...
# 6186  [[25754.0, 25651.1007238, 10.1523417629], [177...
# 6187  [[nan, 874.097913265, 6.77319239829], [nan, 70...
# 6188  [[16421.0, 16393.7292555, 9.70465417822], [161...
# 6189  [[5382.0, 5558.13319633, 8.62301757481], [7060...
# 6190  [[10886.0, 11624.266807, 9.3608501581], [17164...
# 6191  [[55309.0, 52780.4123067, 10.8738954218], [435...
# 6192  [[10240.0, 10638.9913771, 9.27228096301], [nan...
# 6193  [[nan, 896.429509941, 6.79841966189], [nan, 49...
# 6194  [[6958.0, 6976.82969016, 8.85034989346], [1318...
# 6195  [[25500.0, 25290.7134532, 10.1381925501], [240...
# 6196  [[728.0, 712.829606365, 6.5692424106], [3990.0...
# 6197  [[nan, 5491.2057199, 8.6109031315], [nan, 5412...
#
#                                             street_vars  \
# 0     [[10075, DEXTER AVE N, DEXTER AVE N BETWEEN RE...
# 1     [[9725, COLUMBIA ST, COLUMBIA ST BETWEEN ALASK...
# 2     [[3658, 24TH AVE SW, 24TH AVE SW BETWEEN SW WE...
# 3     [[8972, AURORA AVE N, AURORA AVE N BETWEEN N 9...
# 4     [[1410, 11TH AVE NE, 11TH AVE NE BETWEEN NE 47...
# 5     [[8984, AURORA AVE N, AURORA AVE N BETWEEN N 1...
# 6     [[9311, BOREN AVE, BOREN AVE BETWEEN CHERRY ST...
# 7     [[11068, JOHN ST, JOHN ST BETWEEN QUEEN ANNE A...
# 8     [[4373, 3RD AVE, 3RD AVE BETWEEN YESLER WAY AN...
# 9     [[2030, 15TH AVE NE, 15TH AVE NE BETWEEN NE CA...
# 10    [[8870, ASHWORTH AVE N, ASHWORTH AVE N BETWEEN...
# 11    [[2650, 19TH AVE, 19TH AVE BETWEEN E PINE ST A...
# 12    [[2534, 18TH AVE, 18TH AVE BETWEEN E ALDER ST ...
# 13    [[9443, BROADWAY, BROADWAY BETWEEN MARION ST A...
# 14    [[9374, BOYLSTON AVE, BOYLSTON AVE BETWEEN E P...
# 15    [[10733, GREENWOOD AVE N, GREENWOOD AVE N BETW...
# 16    [[8157, 7TH AVE, 7TH AVE BETWEEN UNION ST AND ...
# 17    [[8279, 8TH AVE, 8TH AVE BETWEEN CONVENTION CT...
# 18    [[1189, 1ST AVE S, 1ST AVE S BETWEEN S KING ST...
# 19    [[9446, BROADWAY, BROADWAY BETWEEN E UNION ST ...
# 20    [[1549, 12TH AVE, 12TH AVE BETWEEN E HOWELL ST...
# 21    [[2748, 2ND AVE, 2ND AVE BETWEEN YESLER WAY AN...
# 22    [[4632, 30TH AVE NE, 30TH AVE NE BETWEEN LAKE ...
# 23    [[10126, DRAVUS ST, DRAVUS ST BETWEEN QUEEN AN...
# 24    [[21819, SW AVALON WAY, SW AVALON WAY BETWEEN ...
# 25    [[9477, BROOKLYN AVE NE, BROOKLYN AVE NE BETWE...
# 26    [[10015, DENNY WAY, DENNY WAY BETWEEN WESTLAKE...
# 27    [[10457, FLORENTIA ST, FLORENTIA ST BETWEEN 1S...
# 28    [[3552, 24TH AVE E, 24TH AVE E BETWEEN E BOSTO...
# 29    [[12381, RAINIER AVE S, RAINIER AVE S BETWEEN ...
# ...                                                 ...
# 6168  [[12970, STONE WAY N, STONE WAY N BETWEEN N 46...
# 6169  [[3724, 25TH AVE NE, 25TH AVE NE BETWEEN NE 54...
# 6170  [[8991, AURORA AVE N, AURORA AVE N BETWEEN N 1...
# 6171  [[10180, EASTLAKE AVE E, EASTLAKE AVE E BETWEE...
# 6172  [[5358, 35TH AVE NE, 35TH AVE NE BETWEEN NE 62...
# 6173  [[2771, 2ND AVE, 2ND AVE BETWEEN 2ND WR AVE AN...
# 6174  [[1182, 1ST AVE NW, 1ST AVE NW BETWEEN NW 140T...
# 6175  [[8152, 7TH AVE, 7TH AVE BETWEEN JAMES ST AND ...
# 6176  [[8989, AURORA AVE N, AURORA AVE N BETWEEN N 1...
# 6177  [[12189, PIKE PL, PIKE PL BETWEEN PIKE ST AND ...
# 6178  [[4381, 3RD AVE, 3RD AVE BETWEEN SENECA ST AND...
# 6179  [[4387, 3RD AVE, 3RD AVE BETWEEN VIRGINIA ST A...
# 6180  [[1784, 13TH AVE S, 13TH AVE S BETWEEN S FORES...
# 6181  [[9483, BROOKLYN AVE NE, BROOKLYN AVE NE BETWE...
# 6182  [[8522, 9TH AVE, 9TH AVE BETWEEN OLIVE WAY AND...
# 6183  [[9694, CLOVERDALE PL S, CLOVERDALE PL S BETWE...
# 6184  [[8667, AIRPORT WAY S, AIRPORT WAY S BETWEEN S...
# 6185  [[2037, 15TH AVE NE, 15TH AVE NE BETWEEN NE 50...
# 6186  [[3722, 25TH AVE NE, 25TH AVE NE BETWEEN NE 49...
# 6187  [[1337, 10TH AVE S, 10TH AVE S BETWEEN S SULLI...
# 6188  [[9308, BOREN AVE, BOREN AVE BETWEEN TERRACE S...
# 6189  [[9213, BELLEVUE AVE, BELLEVUE AVE BETWEEN E P...
# 6190  [[12652, ROOSEVELT WAY NE, ROOSEVELT WAY NE BE...
# 6191  [[11903, MONTLAKE BR, MONTLAKE BR BETWEEN POIN...
# 6192  [[8529, 9TH AVE N, 9TH AVE N BETWEEN DENNY WAY...
# 6193  [[1379, 11TH AVE, 11TH AVE BETWEEN E TERRACE S...
# 6194  [[2027, 15TH AVE NE, 15TH AVE NE BETWEEN NE BO...
# 6195  [[9318, BOREN AVE, BOREN AVE BETWEEN UNION ST ...
# 6196  [[1996, 15TH AVE, 15TH AVE BETWEEN E PIKE ST A...
# 6197  [[2018, 15TH AVE E, 15TH AVE E BETWEEN E HIGHL...
#
#       intersection_adt_hat2 zoning_cats min_pavement_cond avg_pavement_cond  \
# 0              35221.303413    0.500000              26.0         70.333333
# 1               8186.717943    0.500000              18.0         36.250000
# 2               7133.591660    0.250000               6.0         42.000000
# 3              37807.610313    0.333333              90.0         90.000000
# 4              26798.066920    0.500000              60.0         77.750000
# 5              59413.562338    0.250000             100.0        100.000000
# 6              20600.394697    0.250000              12.0         51.000000
# 7              11349.514696    0.250000              18.0         34.750000
# 8              15337.621962    0.250000              60.0         75.500000
# 9              17282.761312    0.666667              49.0         82.333333
# 10             23144.159917    0.250000              79.0         93.000000
# 11             25288.011605    0.500000              14.0         50.500000
# 12              6546.135073    0.250000              12.0         53.666667
# 13             33979.231575    0.500000              82.0         92.250000
# 14             12761.784478    0.500000              13.0         49.000000
# 15              1300.956802    0.333333              55.0         65.000000
# 16             21554.779346    0.500000              53.0         62.000000
# 17             18105.376624    0.500000              70.0         79.500000
# 18             15948.657224    0.250000              54.0         73.500000
# 19             26624.189764    0.500000              55.0         81.750000
# 20             12218.105628    0.250000               7.0         42.000000
# 21             14864.533665    0.500000              33.0         62.250000
# 22             23581.375844    0.500000              19.0         62.750000
# 23             23423.627247    0.333333              40.0         43.333333
# 24             14361.313335    0.500000              49.0         67.250000
# 25              7899.115342    0.500000              52.0         66.000000
# 26             32903.833007    0.250000              61.0         72.333333
# 27              4744.231519    0.250000              25.0         31.000000
# 28             20972.138137    0.250000              43.0         50.000000
# 29             33270.431250    0.333333              62.0         83.000000
# ...                     ...         ...               ...               ...
# 6168           12725.376562    0.250000              51.0         57.500000
# 6169           25110.437945    0.250000              26.0         54.750000
# 6170           43877.335230    0.500000              15.0         18.000000
# 6171           18154.722137    0.500000              12.0         26.750000
# 6172           21527.915707    0.250000              60.0         72.750000
# 6173           34476.259330    0.500000              81.0         89.333333
# 6174            1271.654579    0.333333              71.0         79.000000
# 6175           39075.399809    0.250000              44.0         52.000000
# 6176           39280.232780    0.333333              95.0         95.000000
# 6177            1993.186978    0.500000               NaN               NaN
# 6178           16297.356928    0.250000              25.0         67.250000
# 6179           12618.747601    0.250000              31.0         49.500000
# 6180            1622.990971    0.250000              57.0         73.000000
# 6181           22695.687598    0.250000              40.0         73.500000
# 6182           10303.417302    0.250000              51.0         61.500000
# 6183           22033.489005    0.250000              20.0         51.250000
# 6184           22427.713803    0.333333              36.0         77.000000
# 6185            9685.250714    0.250000               1.0         64.750000
# 6186           31900.923085    0.333333              19.0         49.250000
# 6187           11463.080317    0.250000              81.0         89.500000
# 6188           19582.426062    0.250000              37.0         67.000000
# 6189            7055.411893    0.333333              19.0         20.666667
# 6190           38575.505005    0.500000              74.0         79.250000
# 6191           58537.130390    0.500000              57.0         62.000000
# 6192           35220.042676    0.500000              61.0         73.000000
# 6193            5766.937246    0.333333              19.0         54.333333
# 6194           33316.722873    0.333333              70.0         89.000000
# 6195           43418.388606    0.500000              73.0         79.750000
# 6196           20699.381225    0.250000              66.0         73.333333
# 6197            7082.440954    0.333333              17.0         34.333333
#
#       pct_truck_routes  min_surface_width  avg_surface_width  pct_oneway
# 0             0.250000               28.0          51.000000    0.250000
# 1             0.000000               34.0          39.500000    0.500000
# 2             0.000000               23.0          33.250000    0.000000
# 3             0.666667               30.0          30.000000    0.000000
# 4             0.000000               40.0          40.000000    0.500000
# 5             1.000000               40.0          48.000000    0.000000
# 6             0.000000               30.0          38.000000    0.000000
# 7             0.000000               32.0          37.000000    0.500000
# 8             0.000000               42.0          44.000000    0.000000
# 9             0.000000               34.0          52.666667    0.333333
# 10            0.000000               25.0          32.500000    0.000000
# 11            0.000000               42.0          42.500000    0.000000
# 12            0.000000               24.0          36.000000    0.000000
# 13            0.000000               48.0          50.000000    0.000000
# 14            0.000000               25.0          37.500000    0.000000
# 15            0.000000               25.0          34.666667    0.000000
# 16            0.000000               33.0          37.500000    0.500000
# 17            0.000000               27.0          31.500000    0.500000
# 18            0.000000               73.0          76.000000    0.250000
# 19            0.000000               48.0          51.000000    0.000000
# 20            0.000000               24.0          37.000000    0.000000
# 21            0.000000               42.0          48.000000    0.500000
# 22            0.000000               24.0          39.500000    0.000000
# 23            0.666667               32.0          46.666667    0.000000
# 24            0.000000               25.0          39.500000    0.000000
# 25            0.000000               34.0          39.500000    0.500000
# 26            0.000000               24.0          35.500000    0.000000
# 27            0.000000               25.0          25.000000    0.000000
# 28            0.000000               25.0          39.666667    0.000000
# 29            0.000000               42.0          48.666667    0.000000
# ...                ...                ...                ...         ...
# 6168          0.000000               25.0          39.500000    0.000000
# 6169          0.000000               40.0          45.250000    0.000000
# 6170          0.500000               28.0          37.500000    0.000000
# 6171          0.000000               25.0          38.750000    0.000000
# 6172          0.000000               32.0          37.500000    0.000000
# 6173          0.500000               42.0          50.000000    0.250000
# 6174          0.000000               20.0          20.666667    0.000000
# 6175          0.000000               38.0          46.333333    0.500000
# 6176          0.666667               55.0          55.000000    0.000000
# 6177          0.000000               45.0          45.000000    1.000000
# 6178          0.000000               34.0          41.750000    0.500000
# 6179          0.000000               44.0          49.000000    0.500000
# 6180          0.000000               25.0          25.000000    0.000000
# 6181          0.000000               40.0          40.000000    0.000000
# 6182          0.000000               41.0          41.750000    1.000000
# 6183          0.000000               30.0          42.000000    0.000000
# 6184          0.666667               58.0          67.333333    0.000000
# 6185          0.000000               23.0          32.000000    0.000000
# 6186          0.000000               28.0          42.250000    0.000000
# 6187          0.000000               25.0          33.500000    0.000000
# 6188          0.000000               29.0          37.500000    0.000000
# 6189          0.000000               24.0          36.000000    0.000000
# 6190          0.000000               46.0          52.750000    0.000000
# 6191          0.500000               52.0          61.333333    0.000000
# 6192          0.000000               42.0          42.500000    0.000000
# 6193          0.000000               30.0          38.000000    0.000000
# 6194          0.333333               50.0          74.333333    0.000000
# 6195          0.000000               48.0          52.250000    0.000000
# 6196          0.000000               24.0          38.000000    0.000000
# 6197          0.000000               30.0          44.000000    0.000000
#
# [6198 rows x 98 columns]

# %%
# first drop temporary columns
inter_collis_df_final = inter_collis_df.drop('street_vars', axis=1)
inter_collis_df_final.drop('exp_pred_vars', axis=1, inplace=True)

# write to file
inter_collis_df_final.to_csv('./collisions_intersections_rod.tsv', sep="\t", index=False)
